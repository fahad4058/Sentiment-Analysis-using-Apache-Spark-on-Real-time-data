# %% [markdown]
# ## Initialization and Importing Necessary Libraries

# %%
import os
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

import findspark
findspark.init()
findspark.find()
import pyspark
import socket

from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import functions as F
from textblob import TextBlob
from pyspark.streaming import StreamingContext

from pyspark.sql.types import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
import time
import tweepy
import pandas as pd
from tweepy import OAuthHandler 
from tweepy import Stream

# %% [markdown]
# ## Twitter API authorization

# %%
### Unique secret keys which provides access to the twitter API 
### ********** SECRET KEYS *****************

consumer_key="Insert here"
consumer_secret="Insert here"
bearer_token="Insert here"
access_token="Insert here"
access_secret="Insert here"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
redirect_url = auth.get_authorization_url()
print(redirect_url)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=zduuMgAAAAABXvBtAAABfnLy1ww

# %%
api = tweepy.API(auth)

# %% [markdown]
# ## Creating a Spark Session

# %%
### Creates a spark session 
### set name of the app and configurations 
conf = pyspark.SparkConf().setAppName('sentimentanalysis').setMaster('local[2]')
sc = pyspark.SparkContext('local[4]',conf=conf)
spark = SparkSession(sc)
sqlcontext=SQLContext(sc)

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://141.26.191.245:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[4]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>sentimentanalysis</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Defining Twitter Listner Class

# %%
### Stream listener Class establishes a streaming session and allows to 
### read tweets in real time from the twitter API
### Useful for reading a very large number of tweets 
### Functions can be added in the stream listner class as requirement changes

class MyStreamListener(tweepy.Stream):
    
    # time_limit specifies the time duration in which tweets are to be downloaded in real time
    # User can specify the time limit according to the needs
    # time module gives the current time 
    def __init__(self,time_limit):
        self.start_time = time.time()
        self.limit = time_limit
        # hashtag_list stores all the hashtags as a list
        self.hashtag_list=[]
        # tweet_list stores all the tweets as a list 
        self.tweet_list=[]
        # stream instance gets authorized to stream tweets
        super(MyStreamListener, self).__init__(consumer_key,consumer_secret,\
                                               access_token,access_secret)
    
    def on_connect(self):
        print("Connected to Twitter API.")
        
    def on_status(self, status):
        # Tweet ID
        tweet_id = status.id
        # User ID
        user_id = status.user.id
        # Username
        username = status.user.name
        # Tweet
        
        if status.truncated == True:
            tweet = status.extended_tweet['full_text']
            # tweet list is appended with a new tweet
            self.tweet_list.append(tweet)
            hashtags = status.extended_tweet['entities']['hashtags']
        else:
            tweet = status.text
            # tweet list is appended with a new tweet
            self.tweet_list.append(tweet)
            hashtags = status.entities['hashtags']
        
        print(tweet)
        
        # Read hastags
        hashtags=read_hashtags(hashtags)
        # Create Hashtags list
        for ele in hashtags:
            self.hashtag_list.append(ele)
       
        # Retweet count
        retweet_count = status.retweet_count
        # Language
        lang = status.lang
        # If the time limit is reached the stream session is disconnected     
        if (time.time() - self.start_time) > self.limit:
            print(time.time(), self.start_time, self.limit)
            MyStreamListener.disconnect(self)
            return False
             
    def on_error(self, status_code):
        if status_code == 420:
            # Returning False in on_data disconnects the stream
            MyStreamListener.disconnect(self)
            return False

# %%
### Function that reads hashtags, indecies and returns only the hashtags in the form of a list
def read_hashtags(tag_list):
    hashtags = []
    for tag in tag_list:
        hashtags.append(tag['text'])
    return hashtags

# %% [markdown]
# ## Data Cleaning and Pre-processing Functions

# %%
### Function to remove emoticons, symbols, flags and irrelevant objects from the tweets
import re
def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

remove_emojis_udf= udf(lambda x: remove_emojis(x),StringType())

# %%
#### Function to remove https, RT, hashtag symbols etc from the tweets
#### Pre-processing and cleaning of tweet data
def preprocessing(lines):
    words = lines.select(explode(split(lines.value, "t_end")).alias("text"))
    words = words.na.replace('', None)
    words = words.na.drop("any")
    words = words.distinct()
    words = words.withColumn('text', regexp_replace('text', r'http\S+', ''))
    words = words.withColumn('text', regexp_replace('text', '@\w+', ''))
    words = words.withColumn('text', regexp_replace('text', '#', ''))
    words = words.withColumn('text', regexp_replace('text', 'RT', ''))
    words = words.withColumn('text', regexp_replace('text', ':', ''))
    words = words.withColumn('text', regexp_replace('text', "[^A-Za-z0-9]+"," "))
    words = words.withColumn('text', regexp_replace('text', '  ', ' '))
    words = words.withColumn('text', regexp_replace('text', '   ', ' '))
    words = words.withColumn('text', regexp_replace('text', '-', ''))
    words = words.withColumn('text', regexp_replace('text', '&amp;', ''))
    words = words.withColumn('text', regexp_replace('text', '&quot;', ''))
    words = words.withColumn('text', regexp_replace('text', '&gt;', ''))
    words = words.withColumn('text', regexp_replace('text', '&it;', ''))
    words = words.withColumn('text', lower(words["text"]))
    words = words.withColumn('text', remove_emojis_udf("text"))
    #words = words.withColumn('text', tweets_translateudf("text"))
    
    return words

# %% [markdown]
# ## Text Classification and Sentiment Analysis Functions

# %%
# text classification
### Textblob is used here for sentiment analysis
### Important tool for NLP
def polarity_detection(text):
    return TextBlob(text).sentiment.polarity
def subjectivity_detection(text):
    return TextBlob(text).sentiment.subjectivity
def getSentimentScore(text):
    analyzer = SentimentIntensityAnalyzer()
    score = analyzer.polarity_scores(text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    if neg > pos:
        return  "negative"
    elif pos > neg:
        return "positive"
    else:
        return "neutral"

def text_classification(words):
    # polarity detection
    polarity_detection_udf = udf(polarity_detection, StringType())
    words = words.withColumn("polarity", polarity_detection_udf("text"))
    # subjectivity detection
    subjectivity_detection_udf = udf(subjectivity_detection, StringType())
    words = words.withColumn("subjectivity", subjectivity_detection_udf("text"))
    # Sentiment score
    getSentimentScore_udf=udf(lambda x: getSentimentScore(x),StringType())
    words = words.withColumn("sentiment", getSentimentScore_udf("text"))
    return words

# %% [markdown]
# ### Create a Twitter Stream to read tweets and respective hashtags
# #### Tracks tweets based off a keyword and language for a specific time frame

# %%
keyword = input("Please enter keyword or hashtag to search: ")
stream_time_limit = int(input ("Please enter the stream time limit in seconds: "))
lang = input("Please enter the tweets language filter: ")
# Out:
# Please enter keyword or hashtag to search: Ronaldo
# Please enter the stream time limit in seconds: 500
# Please enter the tweets language filter: en

# %%
### Instantiates the stream object that creates a stream session 
### Tweets are filtered w.r.t keyword/hashtag and language. 
### Stream session is disconnect as soon as the stream time limit has been reached
twitter_stream = MyStreamListener(time_limit=stream_time_limit)
twitter_stream.filter(track=[keyword],languages=[lang])
# Out:
# Connected to Twitter API.
# RT @MUFCScoop: Cristiano Ronaldo is set to leave Manchester United in the summer if the club do not qualify for the Champions League. There…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @CristianoXtra_: Dani Alves:
#
# "You can doubt about signing a 38-year-old player, but not if your name is Dani Alves, Messi, Cristiano Ro…
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @SkySportsPL: "We play for the same team, football." ⚽❤️
#
# Pele congratulates Cristiano Ronaldo for receiving The Best FIFA Special Award…
# RT @FootballFunnnys: 🗣️ Cristiano Ronaldo on Sporting Lisbon:
#
# "I will retire there. I have to give it to them even if it is one season of…
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# RT @kshitijshah23: He didn't mention Ronaldo, you know your stocks are low when someone's talking about Anthony Martial and not you 😭.
# RT @Sachk0: Siuuuuu
#
# Maja Markovski went viral with her Cristiano Ronaldo-inspired celebration in the A-Leagues.
#
# I had a chat with the @go…
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @CristianoXtra_: Dani Alves:
#
# "You can doubt about signing a 38-year-old player, but not if your name is Dani Alves, Messi, Cristiano Ro…
# RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9…
# RT @SkySportsPL: "We play for the same team, football." ⚽❤️
#
# Pele congratulates Cristiano Ronaldo for receiving The Best FIFA Special Award…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# My predicted line up tonight #mufc
#
# De gea
# Dalot
# Varane
# Lindelof
# Shaw
# Mctom
# Fred
# Bruno
# Ronaldo
# Elanga
# Greenwood
# @muzamil007_yt @FutArcade @FutSheriff Fr Ronaldo was the only player I wanted to get
# RT @EverythingCR7_: Ronaldo has dominated football in a way no one can ever imagine 🐐 https://t.co/V0KRoS583O
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# RT @Messismo__: So you’re telling me Messi is the leading goal scorer of the decade, and also the top assister of the decade, while also co…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @kshitijshah23: He didn't mention Ronaldo, you know your stocks are low when someone's talking about Anthony Martial and not you 😭.
# STANDARD Transfer news LIVE! Cristiano Ronaldo to exit Man United? Lingard to Newcastle; Vlahovic, Chelsea latest today
#
# Transfer news LIVE!
#
# https://t.co/DhXAWHSWRK
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# Tank top 4 so Ronaldo and Rangnick both piss off, then just let Fletcher and Murtough cook freely
# RT @kshitijshah23: He didn't mention Ronaldo, you know your stocks are low when someone's talking about Anthony Martial and not you 😭.
# Rt if u have more points tha Maguire
# RT @Ishanculer: Rasssss No wonder Ronaldo robbed so many awards until 2015. https://t.co/0zC7253LZt
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @UtdFaithfuls: Cristiano Ronaldo scored these 3 screamers in the UCL in one calendar year for Man Utd and Real Madrid (2009). 🥶
# https://…
# @Madridismo187 show Ronaldo's own pls
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# RT @EverythingCR7_: Ronaldo has dominated football in a way no one can ever imagine 🐐 https://t.co/V0KRoS583O
# RT @brahm00_: Ronaldo fans saying that 2010s is from 2011-2020. I'm done lmao
# RT @TheUnitedDevils: Rangnick: "Right now, I think both [Ronaldo and Rashford] could be available [to face Brentford]."
# #MUFC [MUTV]
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @UtdWesleyy: Cristiano Ronaldo’s trademark ‘SIU’ celebration is rapidly becoming the most iconic celebration in sporting history.😅
# RT @TimelineCR7: CRISTIANO RONALDO PLAYS FOOTBALL TODAY. https://t.co/YMU7OdPQ83
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# RT @ESPNFC: Leo Messi joins Cristiano Ronaldo as the only athletes with 300M+ followers on Instagram 📲 https://t.co/oklISKnwZl
# @ManLikeMartial9 I’m on about the fans defending it. I’d actually be happy if Ronaldo left lol I’d rather keep Martial
# Wouldn’t mind Elanga starting again tonight. Cavani needs some rest and Ronaldo and Rashford aren’t fully fit yet so I would like Greenwood to start down the middle.
# RT @FPLFella: I guess if no doubles are added for GW23 then the captain options are:
#
# 🔹TAA
# 🔹Jota
# 🔹Ronaldo
# 🔹Bruno
# 🔹Cancelo
# @kshitijshah23 He’s doing it cuz usually he says Ronaldo and he proceeds to deliver a stinker
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# @Andsolskjaerha1 @jaydalyutd Signed Ronaldo didn't we? Innocent until proven guilty by it get the point.
# Ndidi if we have cash
# Zakaria if not.
# Both realistic and getable.
# Hearing very strong rumours that Ronaldo has NOT traveled to Turf Moor today
# @buckz_lfc Man utd are better this season with Ronaldo then they were last season would you agree
# RT @CristianoXtra_: Melbourne Victory player Maja Markovski on celebrating like Cristiano Ronaldo.❤️
#
# https://t.co/ZOXZQFuPS0
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# Ronaldo-To-Leave-Man-United-If-They-Fail-To-Qualify-For-The-Champions-League- https://t.co/cL5MxgguJG
# RT @GiveMeSport: Cristiano Ronaldo: "He made me the world's best striker."
#
# Arsene Wenger: "If you love watching football, you love Mesut O…
# RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9…
# @TMForever30 @braahmiin But but ronaldo has more record in cl😂🐵👍
# @TheRanger029 @LuisPrimez @FUTZONEFIFA throwback to when ronaldo is good
# RT @Letter_to_Jack: “I didn’t vote Lewandoski because he has not one anything for Germany”
#
# This is just the thinking of one of the 176 jo…
# RT @FIFAWorldCup: One of the all-time greats 🙌  🏆
#
# Here’s #TheBest FIFA Special Award winner @Cristiano Ronaldo on breaking records and l…
# How Man Utd will line up vs Brentford. #BREMUN #MUFC
#
#                           De Gea
#    Dalot    Varane      Lindelof     Telles
#                            Matic
#                  Bruno         Fred
#    Sancho         Ronaldo            Martial
# @OdegaardEsque @DerKaiserBM No one is stopping Ronaldo and Messi from scoring. Maybe man utd is stoping Ronaldo but Messi is in psg 11 points clear on the 1st place trio with Mbappe and Neymar, that's only his fault that he scored only 1 league goal.
# RT @OddsOnFPL: It seems like Harry Maguire got in trouble with his FPL team after transferring out Cristiano Ronaldo this gameweek.
#
# His FP…
# RT @Letter_to_Jack: “I didn’t vote Lewandoski because he has not one anything for Germany”
#
# This is just the thinking of one of the 176 jo…
# @toby7_ @Cristiano LOL literally the worst thing you can do is criticize ronaldo. Hatrick incoming
# @FLUORITEYES He's a foward who scores off runs he's kinda like 17/18 Ronaldo chelsea or tuchel plays him like a target man
# RT @Mysticalleo_: Cristiano Ronaldo has 0 International POTT in 20 years..
# RT @NathnaelKebede: Cristiano Ronaldo OWNS the Champions League 🐐👑 https://t.co/ziiJvJqpqx
# RT @mr___honey: I really can't believe that Sudhir Ruparelia is richer than Christiano Ronaldo!!! I just googled their networth, fck!!💀😂🙌🏿😂😂
# RT @tweetbyGerard: @mr___honey @SmithNaturinda 😂😂 Ronaldo is richer than him man😂
# RT @Messismo__: So you’re telling me Messi is the leading goal scorer of the decade, and also the top assister of the decade, while also co…
# RT @KSMBRAND: Seungmin got featured in this article for doing Cristiano Ronaldo’s goal celebration during their Expo2020 in Dubai!
#
# 🔗https:…
# @zorchch 🤣🤣🤌🤌 wait for Ronaldo to win champion league
# Can confirm!
# RT @FootballFunnnys: 🗣️ Cristiano Ronaldo on Sporting Lisbon:
#
# "I will retire there. I have to give it to them even if it is one season of…
# @abhishekmah98 Check this Article
# https://t.co/vlBwUAjYZr
# RT @JackRosser_: As reported elsewhere, Newcastle have asked about a loan for Lingard.
#
# Throughout the window so far, Lingard's preference…
# RT @TimelineCR7: How Cristiano Ronaldo's 17/18 didn't win Fifa The Best while Messi's 18/19 did, will forever be a mystery.
#
# Unreal bias ag…
# RT @FootballFactly: Most goals scored since 2020:
#
# Lewandowski: 120
# Ronaldo: 91
# Haaland: 90
# Mbappe:84
#
# Blessed to watch them Weekly 🐐 https…
# RT @WaruiJohn2: Christiano Ronaldo first hat trick tonight..who says No🤔💥💥
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# @thorskarlsefni He is the only messi-ronaldo hybrid player if u deepen it
# RT @jasonaldoooo: Ronaldo at Real Madrid was the epitome of excellence. 🐐🇪🇸 https://t.co/njqlvdo1I1
# RT @ESPNFC: Leo Messi joins Cristiano Ronaldo as the only athletes with 300M+ followers on Instagram 📲 https://t.co/oklISKnwZl
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# RT @Letter_to_Jack: “I didn’t vote Lewandoski because he has not one anything for Germany”
#
# This is just the thinking of one of the 176 jo…
# RT @ESPNFC: Leo Messi joins Cristiano Ronaldo as the only athletes with 300M+ followers on Instagram 📲 https://t.co/oklISKnwZl
# RT @SuperiorBetz: 💰GIVEAWAY💰
# IF RONALDO OR TONEY SCORES FIRST TODAY WE WILL GIVEAWAY AN AMAZON GIFT VOUCHER TO ONE OF YOU.
# Simply follow…
# RT @Joshua_Ubeku: Messi voted for Benzema, an archrival for so many years. Ronaldo did not vote for Benzema, his former teammate who had a…
# RT @TheUnitedDevils: Confirmed Manchester United squad members to face Brentford:
#
# De Gea, Heaton, Henderson; Varane, Maguire, Lindelof, T…
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# RT @KSMBRAND: Here’s the video of Seungmin doing Cristiano Ronaldo’s ‘SIUUUU!’ celebration!
#
# https://t.co/hrnqx3Wshc
# RT @popsszn: Ei fee paying
# RT @Iamzsekk92: This is what happened the last time we wore our 3rd kit, Tonight Sancho and Ronaldo are scoring again and we are wining thi…
# RT @kshitijshah23: He didn't mention Ronaldo, you know your stocks are low when someone's talking about Anthony Martial and not you 😭.
# RT @goal: Lionel Messi and Cristiano Ronaldo have made the FIFA FIFPRO Men's World XI 𝐅𝐈𝐅𝐓𝐄𝐄𝐍 𝐘𝐄𝐀𝐑𝐒 in a row 😱 https://t.co/6QO0RKoUyk
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# RT @CristianoXtra_: The biggest individual feat is receiving a prestigious award that nobody else has.
#
# Cristiano Ronaldo received The Bes…
# RT @EverythingCR7_: Ronaldo has dominated football in a way no one can ever imagine 🐐 https://t.co/V0KRoS583O
# RT @CristianoXtra_: Dani Alves:
#
# "You can doubt about signing a 38-year-old player, but not if your name is Dani Alves, Messi, Cristiano Ro…
# @noIanology No player has ever reached such levels. Cristiano Ronaldo 11/12. The greatest ever
# https://t.co/R8r5rEwY1E
# RT @ESPNFC: A special trophy for Cristiano Ronaldo 🐐
#
# Add it to the trophy cabinet 🏆 https://t.co/IgAmtkR6aS
# "Without sacrifice you cannot achieve nothing." - Cristiano Ronaldo
#
# https://t.co/xJfUWd12Hd
# RONALDO ATTENDING HARRY'S CONCERT-
# RT @ESPNFC: Leo Messi joins Cristiano Ronaldo as the only athletes with 300M+ followers on Instagram 📲 https://t.co/oklISKnwZl
# @TimelineCR7 Ronaldo 3 goul
# 🎙️ Pele:
#
# "If I had to set up a National Team, Cristiano Ronaldo would be my first pick."
# #Legendary https://t.co/N3lgMfYsyl
# RT @CristianoXtra_: Dani Alves:
#
# "You can doubt about signing a 38-year-old player, but not if your name is Dani Alves, Messi, Cristiano Ro…
# RT @ESPNFC: Leo Messi joins Cristiano Ronaldo as the only athletes with 300M+ followers on Instagram 📲 https://t.co/oklISKnwZl
# @VikingoBlanco6 @Gaviesque @MikhaeIII I mean, Quaresma was seen as more talented than Ronaldo back at Sporting
# RT @ManUnitedZone_: Anthony Martial and Cristiano Ronaldo are both included in the #mufc squad to face Brentford [@ManUtdMEN]
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# RT @AnthonyC_Eri: 🎙️ Pele:
#
# "If I had to set up a National Team, Cristiano Ronaldo would be my first pick."
# #Legendary https://t.co/N3lgMf…
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# RT @kshitijshah23: He didn't mention Ronaldo, you know your stocks are low when someone's talking about Anthony Martial and not you 😭.
# RT @Madridfooty: The way Ronaldo creates space for Marcelo on the left to get the cross in for Bale. 🐐
#
# Real Madrid had 9 players involved…
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# @Utd_Mas @momoalas93 It's Allegri tax tbf. Pirlo was doin well last szn even without ronaldo in the team
# RT @TotalRonnie: Cristiano Ronaldo has inspired an entire generation of football. https://t.co/oOwGSptCCD
# Messi is the GOAT 🐐 #TalkYourTalk if Messi is a goat then Ronaldo is a Ram
# This is the most dumbest tweet I’ve ever seen on this site
# RT @UtdWesleyy: Cristiano Ronaldo’s trademark ‘SIU’ celebration is rapidly becoming the most iconic celebration in sporting history.😅
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# Seems Ronaldo is going to play
# @NishadKK6 @mhan_blak @ThatsSketchyy @balladdict17 @CristianoXtra_ i agree, i never said Messi is finished. His output hasn’t been great this season but it’s too early to tell. Although in all fairness Ronaldo had 53 G/A last season so not far off and he’s 2 and a half years older
# @MUF @Brentford 2x tickets available that I'm selling for Brentford vs Manchester united. DM
# #brentford #man united #premierleague #Ronaldo
# @lfctumble @_Hxzzaa Just sums up a Liverpool fan, No one has mentioned Ronaldo not even Man united and u say “penaldo” 😂
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# RT @Michael_JG7: How Man Utd will line up vs Brentford. #BREMUN #MUFC
#
#                           De Gea
#    Dalot…
# RT @7Eliteanalysis: My predicted line up tonight #mufc
#
# De gea
# Dalot
# Varane
# Lindelof
# Shaw
# Mctom
# Fred
# Bruno
# Ronaldo
# Elanga
# Greenw…
# Catch-cry made famous by the footballer Cristiano Ronaldo has caused confusion and annoyance among players and onlookers alike https://t.co/n0B051kfX0
# Ronaldo In Exit Talks With United Chief https://t.co/ORVP1qrn80  ⚽️⚽️  📲 Bet now via ⟶ https://t.co/0I4IIfDtKQ √ https://t.co/a6Uavwq9gQ
# @Honest_ManUtd @__blackclover Cristiano Ronaldo- Ghostin'  (Lyrics)
# RT @footballisfixed: 15 HIGHEST PAID PLAYERS IN #EPL (£m/yr)
#
# Ronaldo 26.5
# De Bruyne 20.8
# De Gea 19.5
# Sancho 18.2
# Varane 17.7
# Lukaku 16.9
# G…
# @SeamusMufc @martialxtra_ I just don’t want to play Ronaldo man he’s kind of ruined our fluidity and he doesn’t even offer much he’s not even our best goal scorer
# RT @OlaseniFeyisayo: Manchester United will defeat Brentford by 3-0 just know you saw it here first ✍️
# Ronaldo to score
# Van de beek to sco…
# RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9…
# @luqvanderlinde @PaulCowler @chinexxofficial @Football__Tweet Both were nominated for Puskas. And for me and many others Ronaldo one's was better. You can't force your opinion on whole world
# @FPL_FireBall As a Ronaldo owner I disagree 😂
# @XVenom07 I know they’re all shit at pressing but Ronaldo is by far the worst, getting him took us backwards https://t.co/KQzMM6tIsO
# RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9…
# @vicente_lfc Ronaldo. But we know you would be ok with it, cuz that’s what you wanted to hear too. Siiiiuuuu
# RT @ESPNFC: Leo Messi joins Cristiano Ronaldo as the only athletes with 300M+ followers on Instagram 📲 https://t.co/oklISKnwZl
# RT @utdreport: Cristiano Ronaldo responds to Pelé congratulating him on winning #TheBest FIFA Special Award https://t.co/hS7fCCH0UJ
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# RT @ESPNFC: Leo Messi joins Cristiano Ronaldo as the only athletes with 300M+ followers on Instagram 📲 https://t.co/oklISKnwZl
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9…
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# RT @ESPNFC: Leo Messi joins Cristiano Ronaldo as the only athletes with 300M+ followers on Instagram 📲 https://t.co/oklISKnwZl
# RT @Ba4shh: Hosts Brentford have no new injury concerns while visitors Manchester United hope to welcome back Cristiano Ronaldo.
#
# It will…
# RT @sahmen366: I just found out that Lewandowski didn’t vote for Messi in his top 3 between 2014-2020.
#
# Didn’t have Messi, Suarez, Neymar…
# @AjaiRaffael Remove spot goals from Ronaldo na he won't be the highest.. y'all think pk is a sure goal! Most confused fanbase .. Chelsea fans we don't know our problem.. did Jorginho played City game?
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# @StretfordPaddck Ndid telemans n Fernandez done with Ronaldo n another top striker up top if we'd done well this year we could a got mbappe or haaland but they'd laugh at us now shoulda gone all out when we got Ronny hel leave soon btw we took the piss outa him rashford shouldn't lace his boots
# True footy supporters feel the very same about you king @Pele thank you for all you done for the beautiful game! Stay blessed!
# @ConwayStats Because its ronaldo
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# Ronaldo moonwalks ahead of time to go to Princess Peach's Castle to steal dinosaur eggs for  their brother
# Fingers crossed old man Ronaldo isn’t match fit
# @UTDTrey ronaldo scoring hattrick?
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# He has to. Most of us are counting on him.
# RT @WaruiJohn2: Christiano Ronaldo first hat trick tonight..who says No🤔💥💥
# RT @GreenwoodXl: please i am on my KNEES for a Ronaldo hattrick today
# 🏴󠁧󠁢󠁥󠁮󠁧󠁿 Brentford v Man Utd
#
# Norgaard U0.5 shots @ 2.2 (0.5u)
# Ronaldo U3.5 shots @ 1.83 (1u)
# Sancho U1.5 shots @ 1.72 (1.5u)
# Bruno U2.5 shots @ 1.61 (0.75u)
# McTominay U1.5 shots @ 1.72 (0.75u)
#
# Bet365
# De Gea shouldn't be earning more than 250k
# Rashford and Martial should be earning 150k at most
# Shouldn't have signed #7 in the first place
# RT @shegzzy10: Ngl, Ronaldo's SIIIUUUU celebration is iconic.
# Best enjoyed after you score a wonder goal.
# @FIFAWorldCup @FIFAcom Who put ronaldo in this video LOL
# @CJ_KIRIN Ole's problem like ours was signing the wrong ex player. Things fell apart when Ronaldo arrived and things are falling apart with Lukaku arriving 🤷🏾‍♂️
# RT @CristianoXtra_: The biggest individual feat is receiving a prestigious award that nobody else has.
#
# Cristiano Ronaldo received The Bes…
# RT @OddsOnFPL: It seems like Harry Maguire got in trouble with his FPL team after transferring out Cristiano Ronaldo this gameweek.
#
# His FP…
# Good afternoon to anybody who needs a Ronaldo hattrick today
# RT @noororooo: men posting Ronaldo makes me want to hit the block button instantly
# RT @crisxrnldo: Most goals scored since 2020:
#
# Lewandowski: 120
# Ronaldo: 91
# Haaland: 90
# Mbappe: 84
# Lukaku: 74
# Benzema: 74
#
# Ruling football…
# RT @OfficialFPL: 🧢 Cristiano Ronaldo was captained by 1,555,562 managers for Double Gameweek 22...
#
# Will he start in #BREMUN and reward tho…
# @ghettogospel77 I love Ronaldinho but he was lucky bcs he wasn’t in Messi &amp; Ronaldo era
# ISTG
# @MiaSanWarsame The goal difference was quite small, suarez did have way more assists tho. Also you gotta take into account that suarez played in the PL in an average liverpool team. He also did a lot of dirty work for Messi to score same way Benzema did for Ronaldo
# RT @BarcaUniversal: Dani Alves: "You can have doubts about signing a 38 year old player, but not when their name is Dani Alves, Leo Messi,…
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @UtdDistrict: Cristiano Ronaldo on Instagram: “Best caption wins 🤔” https://t.co/oxgBq4g5Wb
# This is what I meant when I said getting Ronaldo took us backwards.
#
# We were already bad at pressing but getting him multiplied our problem by 100 https://t.co/7RDLzA2ExU
# Love the kid, but not benching Ronaldo. Unless youre playing him on the left benching our Charity Chamakh!
# RT @Messismo__: So you’re telling me Messi is the leading goal scorer of the decade, and also the top assister of the decade, while also co…
# @stopthatdegea @barcelionela @Serqcs @Peak_Jr446 @amitrmfc 45 yard goals
# Ronaldo
# - 2
# Pessidog
# -0
# RT @IFTVofficial: Today is Ivan Zamorano’s birthday, the famous 1+8…
#
# At the time, Ronaldo wore the 10 shirt on Inter and Zamorano wore 9.…
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# RT @Sommerfield19: *What’s the difference between Ronaldo and time?*
#
# Time passes.
# @utd_Lewis these ronaldo fans have awful ball knowledge 😭😭😭
# Andy Murray in the mud
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# RT @OfficialFPL: 🧢 Cristiano Ronaldo was captained by 1,555,562 managers for Double Gameweek 22...
#
# Will he start in #BREMUN and reward tho…
# @myconglomerate @MessiFan007 @19_cric @cr7raprhymes Ronaldo is the only reason United are still in the Champions League this season. And he has 8 times more league goals as finished pessi. So have some shame and get a fucking brain  🤡👍
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# Great way to demonstrate the power exercise. Not only does exercising prevent &amp; manage chronic diseases like high blood pressure and diabetes, but it's also antiaging helping you look and feel younger.
#
# ✔ @healthtat for updated health &amp; wellness advice and news! #fitnessgirl
# @Bassu36559966 @raudafcb @Cristiano haha  angry? Poor C Ronaldo , can't get champion in the UK and can't attain the world cup
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# @PyrexPlans @UnitedStandMUFC I would play elagna - Ronaldo - Sancho I think hes done alright And he is due to break out great on the ball
# RT @Letter_to_Jack: “I didn’t vote Lewandoski because he has not one anything for Germany”
#
# This is just the thinking of one of the 176 jo…
# Can't wait for the Bruno haul and Ronaldo 1 pointer tonight🤩
# Then we’re essentially ask players who aren’t good at pressing already to press for both themselves and Ronaldo of ouvres our midfield is going to fail working overtime 😭😭
# RT @UtdDistrict: Cristiano Ronaldo on Instagram: “Best caption wins 🤔” https://t.co/oxgBq4g5Wb
# @wiziano_ At his prime at real madrid only Ronaldo and Messi were better wingers than him. He won everything while being active for most of it and played a major role in the ucl 3 peat
# RT @TimelineCR7: CRISTIANO RONALDO PLAYS FOOTBALL TODAY. https://t.co/YMU7OdPQ83
# I’ve been telling people Auba’s on the same wages as Martial &amp; Cavani. Never seen a players wages mentioned more since Ozil. Look at Sancho ffs.
# Ronaldo has not travelled to Griffin Park for the Brentford game!! ……
#
# #FPL #FPLCommunity
# I am one of the unfortunate souls 😓.. vice captain.. Varane
# RT @lovefootballng: "Without sacrifice you cannot achieve nothing." - Cristiano Ronaldo
#
# https://t.co/xJfUWd12Hd
# RT @starboy__16: Ronaldo in the Fifa World Xl https://t.co/9ZyBg1TPol
# RT @Joshua_Ubeku: Messi voted for Benzema, an archrival for so many years. Ronaldo did not vote for Benzema, his former teammate who had a…
# RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9…
# @cryxwoo Ronaldo
#
# CONCEPT POSTER MAKNAE LINE
# #THESECONDSTEP_CHAPTERONE
# #트레저 #TREASURE
# @treasuremembers
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# Five transfers for Ronaldo with star to LEAVE Man Utd with no Champions League https://t.co/UwBGUEQvQR
# RT @Crisrxno: Men lie, women lie, UEFA’s official account doesn’t lie. Messi only has 3 CLs
# RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9…
# Few more pairs and singles available for Man United vs Westham available dm for info!!!
#
# #Mufctickets #ManUnited #tickets #CR7 #Ronaldo #GGMU #westham
# @ghettogospel77 Funny how none of them come close to Messi or Ronaldo
# RT @ESPNFC: Leo Messi joins Cristiano Ronaldo as the only athletes with 300M+ followers on Instagram 📲 https://t.co/oklISKnwZl
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# @vinnie070 @F4STF4TI Fast fati liking this not realising ur a ronaldo fan lmao
# @C345Sam Just Ronaldo mate😂
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @LSeffz: Tank top 4 so Ronaldo and Rangnick both piss off, then just let Fletcher and Murtough cook freely
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# @cryxwoo Ronaldo
# CONCEPT POSTER MAKNAE LINE
# #THESECONDSTEP_CHAPTERONE
# #트레저 #TREASURE
# @treasuremembers
# @UnitedStandMUFC @NewsUnitedStand Sorry. I know it’s not the point but I’m seriously depressed: so Ronaldo’s going if no top 4. Martial,Pogba,Lingard and Cavani going. Rashford and Sancho in the doldrums. Shaw and AWB rejected. And Bruno not getting his wage demand. It just feels like a sinking ship.🥺 Good news?
# RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9…
# Pressuring our board to sign a midfielder. 👀
# RT @GiveMeSport: Cristiano Ronaldo: "He made me the world's best striker."
#
# Arsene Wenger: "If you love watching football, you love Mesut O…
# RT @TimelineCR7: CRISTIANO RONALDO PLAYS FOOTBALL TODAY. https://t.co/YMU7OdPQ83
# @MUFCHaider Called Ronaldo a r@p!$t
# Cristiano Ronaldo in Hounslow tonight… lol 😂 Imagine saying that in League 2.
# RT @aleaguewomen: Put this celebration in-between Ronaldo and Townsend.
#
# #WeAreALeagues https://t.co/u6CYfsCHaF
# RT @JackRosser_: As reported elsewhere, Newcastle have asked about a loan for Lingard.
#
# Throughout the window so far, Lingard's preference…
# @indykaila @premierleague Keeper, Schmeichel, Defender, Rio, Midfield, Scholes, Forward Shearer? Henry? Rooney, Ronaldo? Aguero? I could go on...
# @FPLGOAT7 Ronaldo will score
# RT @Advaithgoat: Imagine a fan base who thinks messi is the goat but has to constantly make up fake shit to keep him relevant 😂
# RT @Michael_JG7: How Man Utd will line up vs Brentford. #BREMUN #MUFC
#
#                           De Gea
#    Dalot…
# @sammiJohnson20 @Eremosel3 @CfcSheikh ronaldo will have double of his goal tally at Chelsea. look at united’s mid compared to that of Chelsea
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# @FPLGOAT7 Ronaldo (C), Greenwood (VC), Dea Gea, Emerson Royal. I’m expecting 3 😂
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# RT @UtdFaithfuls: Cristiano Ronaldo scored these 3 screamers in the UCL in one calendar year for Man Utd and Real Madrid (2009). 🥶
# https://…
# RT @SkySportsNews: "I believe that he's going to do a good job."
#
# #MUFC's Cristiano Ronaldo says a change of manager at the club has been h…
# RT @Ishanculer: Lionel Messi is always influential for his team unlike Ronaldo 🔥 https://t.co/j30hZmyVmL
# RT @SkySports: "We play for the same team, football." ⚽❤️
#
# Pele congratulates Cristiano Ronaldo for receiving The Best FIFA Special Award…
# RT @MBAPPESEXUAL_: Cristiano Ronaldo owns Lionel Messi Individually and collectively 🤝 https://t.co/WhEAVdhAKt
# RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF…
# RT @Eyeswid04387971: Casillas never voted for Messi during 08-12. Ronaldo left Portugal captaincy so that Bruno Alves can vote for him. Sam…
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# RT @TotalRonnie: Sergio Ramos: “Cristiano Ronaldo is the most important player in the history of Real Madrid.” https://t.co/1o4lUur6iE
# Nice having our pal @rioferdy5 at the offices today exciting times ahead.
#
# Stay tuned to see what’s next @roberto_rudie @aix_capital @official_anfa
#
# #football #soccer #sports #futbol #fifa #sport #premierleague #africanfootball #championsleague #ronaldo #like #follow #futebol https://t.co/7tlrerRVoN
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9…
# RT @MadridProp: Benzema at 19 was a huge sensation that he landed a call from Barcelona in 2008 for Pep's project, a call from SAF for Manc…
# RT @MBAPPESEXUAL_: Cristiano Ronaldo owns Lionel Messi Individually and collectively 🤝 https://t.co/WhEAVdhAKt
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# RT @FutbolZEE: OFFICIAL: Cristiano Ronaldo is in the squad to face Brentford tomorrow. Suiiiiiiiiiiiii!
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# RT @Letter_to_Jack: “I didn’t vote Lewandoski because he has not one anything for Germany”
#
# This is just the thinking of one of the 176 jo…
# @C345Sam RONALDO STARTING OR NOT ? OR I WILL SLEEP
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# Probably better off Maguire plays tonight so Ralf can start Lindelof-Varane vs West Ham on Saturday.
#
# Front 3 will be interesting this evening, personally would like to see Sancho - Ronaldo - Elanga in the XI.
# #MUFC #BREMUN
# RT @OfficialFPL: 🧢 Cristiano Ronaldo was captained by 1,555,562 managers for Double Gameweek 22...
#
# Will he start in #BREMUN and reward tho…
# RT @Ishanculer: Lionel Messi is always influential for his team unlike Ronaldo 🔥 https://t.co/j30hZmyVmL
# RT @CristianoXtra_: Dani Alves:
#
# "You can doubt about signing a 38-year-old player, but not if your name is Dani Alves, Messi, Cristiano Ro…
# RT @kwesiiiiiiiii: Ronaldo has sold his house in Manchester? Lol
# RT @UtdDistrict: Cristiano Ronaldo on Instagram: “Best caption wins 🤔” https://t.co/oxgBq4g5Wb
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @TotalRonnie: Cristiano Ronaldo has inspired an entire generation of football. https://t.co/oOwGSptCCD
# RT @kshitijshah23: He didn't mention Ronaldo, you know your stocks are low when someone's talking about Anthony Martial and not you 😭.
# RT @SkySportsPL: "We play for the same team, football." ⚽❤️
#
# Pele congratulates Cristiano Ronaldo for receiving The Best FIFA Special Award…
# RT @CristianoXtra_: Melbourne Victory player Maja Markovski on celebrating like Cristiano Ronaldo.❤️
#
# https://t.co/ZOXZQFuPS0
# Press Review / #ManchesterUnitedFC #ManchesterUnitedTransferNews Manchester United transfer news RECAP John McGinn latest plus Ronaldo and Pogba updates - Manchester Evening News https://t.co/5DD5JEXQeb SignUp HiPeople https://t.co/rHBI3WzX5o
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# RT @Joshua_Ubeku: Messi voted for Benzema, an archrival for so many years. Ronaldo did not vote for Benzema, his former teammate who had a…
# At last Ronaldo in today. Idk about others but just having Ronaldo in the team, at least we have something to look forward to in a ManUnited games. Oops.
#
# #ManchesterUnited
# Won't happen, but I'd go
# De Gea, Dalot, Varane, Lindelof, Telles, Mctominay, VDB, Bruno, Elanga, Sancho, Ronaldo. #mufc
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @7BDORS_: According to Jose Mourinho it's much harder to be Lionel Messi than it is to be Cristiano Ronaldo 👀 https://t.co/b1pyhBIYyT
# Ronaldo's influence is unmatchable
# RT @kshitijshah23: He didn't mention Ronaldo, you know your stocks are low when someone's talking about Anthony Martial and not you 😭.
# @Strik3s The press really hates Ronaldo :/
# RT @ManUtdMEN: Jones, Martial, Ronaldo ✅
#
# A look at the confirmed squad members vs Brentford #mufc #BREMUN https://t.co/TESOfJbfWb https://…
# @Messi1283969192 @TotalRonnie no goalkeeper in the world would have saved any of them. Pre-2014 Ronaldo struck the ball better than any other player in history
# @OfficialFPL Ronaldo hat trick ffs. My VC was Dennis 🙃
# RT @FplScientist: Who wants Ronaldo to come on for a two minute cameo?!
# RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…
# RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt…
# Ribery on the Messi vs Ronaldo debate: https://t.co/nDAUPD9R7n
# RT @goal: Lionel Messi reaches 300m+ followers on Instagram 🤳
#
# Cristiano Ronaldo is currently sat on 392m 📱 https://t.co/DVkE8srbYO
# RT @MystiqueJerseys: ⏰ Competition Time ⏰
#
# If Cristiano Ronaldo 🇵🇹 or Harry Kane 🏴󠁧󠁢󠁥󠁮󠁧󠁿 score in the Premier League tonight, someone will…
# RT @CristianoXtra_: Dani Alves:
#
# "You can doubt about signing a 38-year-old player, but not if your name is Dani Alves, Messi, Cristiano Ro…
# RT @UtdWesleyy: Cristiano Ronaldo’s trademark ‘SIU’ celebration is rapidly becoming the most iconic celebration in sporting history.😅
# RT @UtdXclusive: 📝 - Victor Lindelof named his #mufc teammate Cristiano Ronaldo as his number one pick for FIFA's TheBest player. [MEN]
# RT @BarcaUniversal: Dani Alves: "You can have doubts about signing a 38 year old player, but not when their name is Dani Alves, Leo Messi,…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# Stream connection closed by Twitter
# RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…
# 1642606560.2139485 1642606058.421151 500

# %% [markdown]
# ### Creating tweets and hashtags dataframes based off the streamed tweets

# %%
### Stream object is accessed to read the hashtag list containing hashtags from all the tweets
### Hashtags list is the converted into a dataframe for further tasks
hashtags_df=spark.createDataFrame(twitter_stream.hashtag_list,StringType())

# %%
### Streamlistner object is accessed again to create a dataframe from the tweets list
### tweet_list contains all the downloaded tweets
tweets_df=spark.createDataFrame(twitter_stream.tweet_list,StringType())

# %%
### Displays the tweets extracted in a dataframe
tweets_df.show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                                        |
# +---------------------------------------------------------------------------------------------------------------------------------------------+
# |RT @MUFCScoop: Cristiano Ronaldo is set to leave Manchester United in the summer if the club do not qualify for the Champions League. There… |
# |RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…|
# |RT @CristianoXtra_: Dani Alves:
#
# "You can doubt about signing a 38-year-old player, but not if your name is Dani Alves, Messi, Cristiano Ro… |
# |RT @cr7raprhymes: Cristiano Ronaldo and Robert Lewandowski are the only players to win back to back FIFA The Best Awards.
#
# Football Royalt… |
# |RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…|
# |RT @SkySportsPL: "We play for the same team, football." ⚽❤️
#
# Pele congratulates Cristiano Ronaldo for receiving The Best FIFA Special Award… |
# |RT @FootballFunnnys: 🗣️ Cristiano Ronaldo on Sporting Lisbon:
#
# "I will retire there. I have to give it to them even if it is one season of… |
# |RT @Betfair: 🎉 It's competition time! We're giving away 5 x £10 free bets!
#
# Leicester v Spurs
# Brentford v Man Utd
#
# ⚽ To be in with a chance…|
# |RT @kshitijshah23: He didn't mention Ronaldo, you know your stocks are low when someone's talking about Anthony Martial and not you 😭.      |
# |RT @Sachk0: Siuuuuu
#
# Maja Markovski went viral with her Cristiano Ronaldo-inspired celebration in the A-Leagues.
#
# I had a chat with the @go… |
# |RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF… |
# |RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…|
# |RT @CristianoXtra_: Dani Alves:
#
# "You can doubt about signing a 38-year-old player, but not if your name is Dani Alves, Messi, Cristiano Ro… |
# |RT @SurpriseShirts: If Cristiano Ronaldo STARTS for Manchester United against Brentford this evening, we'll giveaway a https://t.co/4LKMjq9… |
# |RT @SkySportsPL: "We play for the same team, football." ⚽❤️
#
# Pele congratulates Cristiano Ronaldo for receiving The Best FIFA Special Award… |
# |RT @goal: Australian tennis star Nick Kyrgios hit the Ronaldo celebration after winning his first match at the Australian Open 🎾 https://t.…|
# |My predicted line up tonight #mufc
#
# De gea
# Dalot
# Varane
# Lindelof
# Shaw
# Mctom
# Fred
# Bruno
# Ronaldo
# Elanga
# Greenwood                   |
# |@muzamil007_yt @FutArcade @FutSheriff Fr Ronaldo was the only player I wanted to get                                                         |
# |RT @EverythingCR7_: Ronaldo has dominated football in a way no one can ever imagine 🐐 https://t.co/V0KRoS583O                               |
# |RT @thefootyarena: If Cristiano Ronaldo scores ANYTIME against Brentford tonight, we'll give away a brand new PlayStation 5 console + a FIF… |
# +---------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
### Tweets dataframes Preprocessing and data cleaning
tweets_df=preprocessing(tweets_df)

# %%
### repartioning the data to avoid time out issues considering the volume of data
### Without using repartition error may occur considering the volume of tweets
tweets_df=tweets_df.repartition(1)

# %%
### Displays the cleaned tweets
tweets_df.show(truncate=False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |text                                                                                                                                                                                                                         |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | lionel messi reaches 300m followers on instagram cristiano ronaldo is currently sat on 392m                                                                                                                                 |
# |ribery on the messi vs ronaldo debate                                                                                                                                                                                        |
# |how man utd will line up vs brentford bremun mufc de gea dalot varane lindelof telles matic bruno fred sancho ronaldo martial                                                                                                |
# | ronaldo scoring hattrick                                                                                                                                                                                                    |
# |messi is the goat talkyourtalk if messi is a goat then ronaldo is a ram                                                                                                                                                      |
# | cristiano ronaldo responds to pel congratulating him on winning thebest fifa special award                                                                                                                                  |
# | haha angry poor c ronaldo can t get champion in the uk and can t attain the world cup                                                                                                                                       |
# | ronaldo concept poster maknae line thesecondstep chapterone treasure                                                                                                                                                        |
# | a special trophy for cristiano ronaldo add it to the trophy cabinet                                                                                                                                                         |
# | so you re telling me messi is the leading goal scorer of the decade and also the top assister of the decade while also co                                                                                                   |
# | siuuuuu maja markovski went viral with her cristiano ronaldo inspired celebration in the a leagues i had a chat with the                                                                                                    |
# | no one is stopping ronaldo and messi from scoring maybe man utd is stoping ronaldo but messi is in psg 11 points clear on the 1st place trio with mbappe and neymar that s only his fault that he scored only 1 league goal |
# |i am one of the unfortunate souls vice captain varane                                                                                                                                                                        |
# |fingers crossed old man ronaldo isn t match fit                                                                                                                                                                              |
# | leo messi joins cristiano ronaldo as the only athletes with 300m followers on instagram                                                                                                                                     |
# | my predicted line up tonight mufc de gea dalot varane lindelof shaw mctom fred bruno ronaldo elanga greenw                                                                                                                  |
# | cristiano ronaldo was captained by 1 555 562 managers for double gameweek 22 will he start in bremun and reward tho                                                                                                         |
# | ronaldo will score                                                                                                                                                                                                          |
# | if cristiano ronaldo stas for manchester united against brentford this evening we ll giveaway a                                                                                                                             |
# | anthony martial and cristiano ronaldo are both included in the mufc squad to face brentford                                                                                                                                 |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
### Sentiment analysis on the cleaned data/tweets
tweets = text_classification(tweets_df)

# %%
### Sentiment analysis results
tweets.show()
# Out:
# +--------------------+-------------------+-------------------+---------+
# |                text|           polarity|       subjectivity|sentiment|
# +--------------------+-------------------+-------------------+---------+
# | lionel messi rea...|                0.0|                0.4| positive|
# |ribery on the mes...|                0.0|                0.0|  neutral|
# |how man utd will ...|                0.0|                0.0|  neutral|
# | ronaldo scoring ...|                0.0|                0.0|  neutral|
# |messi is the goat...|                0.0|                0.0|  neutral|
# | cristiano ronald...| 0.4285714285714286| 0.6607142857142857| positive|
# | haha angry poor ...|-0.2333333333333333| 0.6333333333333333| positive|
# | ronaldo concept ...|                0.0|                0.0| positive|
# | a special trophy...|0.35714285714285715| 0.5714285714285714| positive|
# | so you re tellin...|                0.5|                0.5| positive|
# | siuuuuu maja mar...|                0.0|                0.0| positive|
# | no one is stoppi...|0.03333333333333334| 0.7944444444444444| negative|
# |i am one of the u...|               -0.5|                1.0| negative|
# |fingers crossed o...|               0.25|0.30000000000000004| positive|
# | leo messi joins ...|                0.0|                1.0|  neutral|
# | my predicted lin...|                0.0|                0.0|  neutral|
# | cristiano ronald...|                0.0|                0.0| positive|
# |  ronaldo will score|                0.0|                0.0|  neutral|
# | if cristiano ron...|                0.0|                0.0| positive|
# | anthony martial ...|                0.0|                0.0|  neutral|
# +--------------------+-------------------+-------------------+---------+
# only showing top 20 rows

# %%
### Overall Sentiment
sentiment_result=tweets.groupBy("sentiment").count()
sentiment_result.show()
# Out:
# +---------+-----+
# |sentiment|count|
# +---------+-----+
# | positive|   88|
# |  neutral|   65|
# | negative|   34|
# +---------+-----+

# %%
### Plotting a pie chart of the resulting sentiments
from pandas.plotting import table
import matplotlib.pyplot as plt
data=sentiment_result.toPandas()
ax1 = plt.subplot(121, aspect='equal')
data.plot(kind='pie', y = 'count', ax=ax1, autopct='%1.1f%%', figsize=(15,5),
 startangle=45, shadow=True, labels=data['sentiment'], legend = False, fontsize=10)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, data, loc='center')
tbl.scale(1,3)
tbl.auto_set_font_size(False)
tbl.set_fontsize(15)
plt.show()

# %%
### Analyzing the hashtags from the streamed tweets
hashtags_df.withColumn("value",lower("value"))\
.groupBy("value").count().sort("count",ascending=False).show(10)
ht_df=hashtags_df.withColumn("value",lower("value"))\
.groupBy("value").count().sort("count",ascending=False).head(10)
ht_df=pd.DataFrame(ht_df,columns=["Hashtag","count"])
# Out:
# +--------------------+-----+
# |               value|count|
# +--------------------+-----+
# |                mufc|   12|
# |              bremun|    8|
# |             ronaldo|    3|
# |       premierleague|    2|
# |             thebest|    2|
# |thesecondstep_cha...|    2|
# |              트레저|    2|
# |            treasure|    2|
# |           legendary|    2|
# |                 fpl|    1|
# +--------------------+-----+
# only showing top 10 rows

# %%
ht_df.plot.bar(x="Hashtag",y="count")
# Out:
# <AxesSubplot:xlabel='Hashtag'>
